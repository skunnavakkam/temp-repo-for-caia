# %%
from nnsight import LanguageModel
from sae_auto_interp.autoencoders import load_eai_autoencoders

model = LanguageModel('gpt2', device_map='cuda')

submodule_dict, model = load_eai_autoencoders(
    model, 
    [6], 
    weight_dir="kvsudarsh/caia-sae-init", 
    module="res", 
    
)
# Out:
# Fetching 0 files: 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 6
#       2 from sae_auto_interp.autoencoders import load_eai_autoencoders
#       4 model = LanguageModel('gpt2', device_map='cuda')
# ----> 6 submodule_dict, model = load_eai_autoencoders(
#       7     model,
#       8     [6],
#       9     weight_dir="kvsudarsh/caia-sae-init",
#      10     module="res",
#      11 )
#
# File ~/Documents/Github/sae-auto-interp/sae_auto_interp/autoencoders/eleuther.py:48, in load_eai_autoencoders(model, ae_layers, weight_dir, module, randomize, seed, k)
#      46     sae = Sae.load_from_disk(weight_dir+"/"+submodule,device=DEVICE).to(dtype=model.dtype)
#      47 else:
# ---> 48     sae = Sae.load_from_hub(weight_dir,hookpoint=submodule, device=DEVICE).to(dtype=model.dtype)
#      50 if randomize:
#      51     sae = Sae.load_from_hub(weight_dir,hookpoint=submodule, device=DEVICE).to(dtype=model.dtype)
#
# File ~/Documents/Caltech/feature-splitting/venv/lib/python3.11/site-packages/sae/sae.py:128, in Sae.load_from_hub(name, hookpoint, device, decoder)
#     125 elif not repo_path.joinpath("cfg.json").exists():
#     126     raise FileNotFoundError("No config file found; try specifying a layer.")
# --> 128 return Sae.load_from_disk(repo_path, device=device, decoder=decoder)
#
# File ~/Documents/Caltech/feature-splitting/venv/lib/python3.11/site-packages/sae/sae.py:139, in Sae.load_from_disk(path, device, decoder)
#     130 @staticmethod
#     131 def load_from_disk(
#     132     path: Path | str,
#    (...)
#     135     decoder: bool = True,
#     136 ) -> "Sae":
#     137     path = Path(path)
# --> 139     with open(path / "cfg.json", "r") as f:
#     140         cfg_dict = json.load(f)
#     141         d_in = cfg_dict.pop("d_in")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/sudarshanagopalkunnavakkam/.cache/huggingface/hub/models--kvsudarsh--caia-sae-init/snapshots/3566203211749b1aed462fa0ff61cea2664aafa0/layers.6/cfg.json'
